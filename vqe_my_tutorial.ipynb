# %%
# imoprt

# %%
# imports
import numpy as np
from typing import List, Callable
from scipy.optimize import minimize
from scipy.optimize._optimize import OptimizeResult
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector, Operator, SparsePauliOp
from qiskit.primitives import StatevectorSampler, PrimitiveJob
from qiskit.circuit.library import TwoLocal
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit.visualization import plot_histogram
from qiskit_ibm_runtime.fake_provider import FakeSherbrooke
from qiskit_ibm_runtime import Session, EstimatorV2 as Estimator
from qiskit_aer import AerSimulator
# plt.style.use('dark_background')
from qiskit_ibm_runtime import QiskitRuntimeService

# %% [markdown]
# ## Ansatz

# %%
# make an ansats ( Parameterised circuit ) 

''' Following ansats are some given by qiskit

    1. EfficientSU2 
    2. Two-local
    3. Real amplitudes
    4. UCCSD 
    Custom 
    also some approach on using diffusion model ( https://arxiv.org/pdf/2310.02511#:~:text=The%20key%20component%20of%20VQE,performance%20of%20the%20VQE%20algorithm.) 
    
'''

# %%
num_qubits = 3
rotation_blocks = ['ry','rz']
entanglement_blocks = 'cz'
entanglement = 'full'

ansatz = TwoLocal(num_qubits, rotation_blocks, entanglement_blocks,entanglement,reps=1,insert_barriers=True)


### Don't change any code past this line ###
ansatz.decompose().draw('mpl')

# %%
from qiskit.circuit.library import RealAmplitudes
real_ansatz = RealAmplitudes(3, reps=2, flatten = True, insert_barriers = True)  # create the circuit on 3 qubits
real_ansatz.draw()

# %% [markdown]
# ## Setting up hamiltonian
